# %%
import tensorflow as tf
import storage_client as sc

# %%
model_id = "model_5ba417da-ae99-11e7-b873-000c29421ad5"

# %%
ms = sc.ModelStorage()

# %%
sess = ms.loadModel(model_id)
# Out:
# ([{u'model_id': u'model_5ba417da-ae99-11e7-b873-000c29421ad5', u'author': u'faniel', u'score': u'0.917', u'team': u'eve', u'model': Binary('\x1f\x8b\x08\x00~9\xdeY\x00\x03\xed\xbdy U\xdd\xdb?l\x1e\x8e\x99H\xe6\xb1B2d<g\xafEBJ!\xcd)\x12\x8a\x1225\x17\x91D\xe6\x8a\xa2\xd2DI%\xd39g\xef\xb5\x16\x8d\x9a\xd0\xa8\xd2<hRi\x1e4\xbdGs\xdd\xd5\xdd\xf7~\x9e\xe7\xf7\xfc\xde\xf7\xbd\xd7\x1f\xce>{\xb8\xae\xcf5\xaek\xad\xbd\xd6\xd1\xd7B\xe8\x7f\xbcY\n\x9a\xbd\xadm\xd7\xa7\x95\xbd\xad\xe5\xb7\x9f\x9f\x9b\x90U?+;{\x9b~6\xb6\xf6v\x82\xf3\xf6v6\xf6Bz\xb6\xff\xf3\xd0\x84\x84\xe2bb\x03\xa3\xf5\xf4\x84&\x07F\x84\xfd\xee\xbe\xbf\xbb\xfe\xff\xd2\xd6\xd7">0:,pRxH\xcc\xff\x98\'\xfc\xc7\xf6\xb7\xb2\xb2\xb3\xfa\xd7\xfe\xffG\xda\xb7\xf6\xffr\xd47,"8d\xd6\x7f\x1b\x8f.\x03\xdb\xd9\xd9\xfc\xd2\xfe\xd6\xfd\xec\x7f\xb0\xbf\x8d\x9d\xb5\x8d\x90\x9e\xe5\x7f\x1b\x82\xdf\xb4\xff\x9f\xdb_HHBJXCDJXHJm\xd4\'\xfbK\t+K+\x8bJeK(\x8bH\xb1z\'<\x13\xb6M[\x03\xaeK\x89\xa8\x04X\t.\x89u\x9d\xd5\x13\x9c\xed\xdd\xdb\x16\x0c\xeb\xdb\xa7\
# ...

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
mnist
# Out:
# Datasets(train=<tensorflow.contrib.learn.python.learn.datasets.mnist.DataSet object at 0x7fa5b3fdcbd0>, validation=<tensorflow.contrib.learn.python.learn.datasets.mnist.DataSet object at 0x7fa5cefeea10>, test=<tensorflow.contrib.learn.python.learn.datasets.mnist.DataSet object at 0x7fa5b400f7d0>)

# %%
graph = sess.graph

# %%
graph.collections
# Out:
# [u'train_op', u'variables', u'trainable_variables']

# %%
graph.collections
# Out:
# [u'train_op', u'variables', u'trainable_variables']

# %%
graph.get_collection(u'variables')
# Out:
# [<tf.Variable 'Variable:0' shape=(784, 10) dtype=float32_ref>,
#  <tf.Variable 'Variable_1:0' shape=(10,) dtype=float32_ref>]

# %%
graph.get_collection(u'trainable_variables')
# Out:
# [<tf.Variable 'Variable:0' shape=(784, 10) dtype=float32_ref>,
#  <tf.Variable 'Variable_1:0' shape=(10,) dtype=float32_ref>]

# %%
graph.get_collection(u'train_op')
# Out:
# [<tf.Operation 'GradientDescent' type=NoOp>]

# %%
x = graph.get_tensor_by_name("Placeholder:0")

# %%
x
# Out:
# <tf.Tensor 'Placeholder:0' shape=(?, 784) dtype=float32>

# %%
W = graph.get_tensor_by_name("Variable:0")

# %%
W = graph.get_tensor_by_name("Variable_1:0")

# %%
y = graph.get_tensor_by_name("Softmax:0")

# %%
y_ = graph.get_tensor_by_name("Placeholder_1:0")

# %%
correct_prediction = graph.get_tensor_by_name("Equal:0")

# %%
accuracy = graph.get_tensor_by_name("Mean_1:0")

# %%
print(sess.run(accuracy, feed_dict={x: mnist.test.images, y_: mnist.test.labels}))
# Out:
# 0.9179
